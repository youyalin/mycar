# %% [markdown]
# <a href="https://colab.research.google.com/github/youyalin/mycar/blob/master/Copy_of_Copy_of_DonkeyCar_on_Duckiebot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1- 存到你的 Google Drive

# %% [markdown]
# - [CC-BY](http://creativecommons.org/licenses/by/3.0/tw/) [十百千實驗室](https://medium.com/十百千實驗室)

# %% [markdown]
# # 2- Colab Notebook 基本操作

# %% [markdown]
# #確認目前版本

# %%
! pip3 list
# Out:
# Package                  Version
# ------------------------ -----------
# absl-py                  0.8.1
# alabaster                0.7.12
# albumentations           0.1.12
# altair                   3.2.0
# astor                    0.8.0
# astropy                  3.0.5
# atari-py                 0.2.6
# atomicwrites             1.3.0
# attrs                    19.3.0
# audioread                2.1.8
# autograd                 1.3
# Babel                    2.7.0
# backcall                 0.1.0
# backports.tempfile       1.0
# backports.weakref        1.0.post1
# beautifulsoup4           4.6.3
# bleach                   3.1.0
# blis                     0.2.4
# bokeh                    1.0.4
# boto                     2.49.0
# boto3                    1.10.18
# botocore                 1.13.18
# Bottleneck               1.3.0
# branca                   0.3.1
# bs4                      0.0.1
# bz2file                  0.98
# cachetools               3.1.1
# certifi                  2019.9.11
# cffi                     1.13.2
# chainer                  6.5.0
# chardet                  3.0.4
# chart-studio             1.0.0
# Click                    7.0
# cloudpickle              1.2.2
# cmake                    3.12.0
# colorlover               0.3.0
# community                1.0.0b1
# contextlib2              0.5.5
# convertdate              2.2.0
# coverage                 3.7.1
# coveralls                0.5
# crcmod                   1.7
# cufflinks                0.17.0
# cupy-cuda101             6.5.0
# cvxopt                   1.2.3
# cvxpy                    1.0.25
# cycler                   0.10.0
# cymem                    2.0.3
# Cython                   0.29.14
# daft                     0.0.4
# dask                     1.1.5
# dataclasses              0.7
# datascience              0.10.6
# decorator                4.4.1
# defusedxml               0.6.0
# descartes                1.1.0
# dill                     0.3.1.1
# distributed              1.25.3
# Django                   2.2.7
# dlib                     19.18.0
# dm-sonnet                1.35
# docopt                   0.6.2
# docutils                 0.15.2
# dopamine-rl              1.0.5
# earthengine-api          0.1.206
# easydict                 1.9
# ecos                     2.0.7.post1
# editdistance             0.5.3
# en-core-web-sm           2.1.0
# entrypoints              0.3
# et-xmlfile               1.0.1
# fa2                      0.3.5
# fancyimpute              0.4.3
# fastai                   1.0.59
# fastcache                1.1.0
# fastdtw                  0.3.4
# fastprogress             0.1.21
# fastrlock                0.4
# fbprophet                0.5
# feather-format           0.4.0
# featuretools             0.4.1
# filelock                 3.0.12
# fix-yahoo-finance        0.0.22
# Flask                    1.1.1
# folium                   0.8.3
# fsspec                   0.6.0
# future                   0.16.0
# gast                     0.2.2
# GDAL                     2.2.2
# gdown                    3.6.4
# gensim                   3.6.0
# geographiclib            1.50
# geopy                    1.17.0
# gevent                   1.4.0
# gin-config               0.2.1
# glob2                    0.7
# google                   2.0.2
# google-api-core          1.14.3
# google-api-python-client 1.7.11
# google-auth              1.4.2
# google-auth-httplib2     0.0.3
# google-auth-oauthlib     0.4.1
# google-cloud-bigquery    1.21.0
# google-cloud-core        1.0.3
# google-cloud-datastore   1.8.0
# google-cloud-language    1.2.0
# google-cloud-storage     1.16.2
# google-cloud-translate   1.5.0
# google-colab             1.0.0
# google-pasta             0.1.8
# google-resumable-media   0.4.1
# googleapis-common-protos 1.6.0
# googledrivedownloader    0.4
# graph-nets               1.0.5
# graphviz                 0.10.1
# greenlet                 0.4.15
# grpcio                   1.15.0
# gspread                  3.0.1
# gspread-dataframe        3.0.3
# gunicorn                 20.0.0
# gym                      0.15.4
# h5py                     2.8.0
# HeapDict                 1.0.1
# holidays                 0.9.11
# html5lib                 1.0.1
# httpimport               0.5.18
# httplib2                 0.11.3
# humanize                 0.5.1
# hyperopt                 0.1.2
# ideep4py                 2.0.0.post3
# idna                     2.8
# image                    1.5.27
# imageio                  2.4.1
# imagesize                1.1.0
# imbalanced-learn         0.4.3
# imblearn                 0.0
# imgaug                   0.2.9
# importlib-metadata       0.23
# imutils                  0.5.3
# inflect                  2.1.0
# intel-openmp             2020.0.133
# intervaltree             2.1.0
# ipykernel                4.6.1
# ipython                  5.5.0
# ipython-genutils         0.2.0
# ipython-sql              0.3.9
# ipywidgets               7.5.1
# itsdangerous             1.1.0
# jax                      0.1.51
# jaxlib                   0.1.33
# jdcal                    1.4.1
# jedi                     0.15.1
# jieba                    0.39
# Jinja2                   2.10.3
# jmespath                 0.9.4
# joblib                   0.14.0
# jpeg4py                  0.1.4
# jsonschema               2.6.0
# jupyter                  1.0.0
# jupyter-client           5.3.4
# jupyter-console          5.2.0
# jupyter-core             4.6.1
# kaggle                   1.5.6
# kapre                    0.1.3.1
# Keras                    2.2.5
# Keras-Applications       1.0.8
# Keras-Preprocessing      1.1.0
# keras-vis                0.4.1
# kfac                     0.2.0
# kiwisolver               1.1.0
# knnimpute                0.1.0
# librosa                  0.6.3
# lightgbm                 2.2.3
# llvmlite                 0.30.0
# lmdb                     0.98
# lucid                    0.3.8
# lunardate                0.2.0
# lxml                     4.2.6
# magenta                  0.3.19
# Markdown                 3.1.1
# MarkupSafe               1.1.1
# matplotlib               3.1.1
# matplotlib-venn          0.11.5
# mesh-tensorflow          0.1.4
# mido                     1.2.6
# mir-eval                 0.5
# missingno                0.4.2
# mistune                  0.8.4
# mizani                   0.5.4
# mkl                      2019.0
# mlxtend                  0.14.0
# more-itertools           7.2.0
# moviepy                  0.2.3.5
# mpi4py                   3.0.3
# mpmath                   1.1.0
# msgpack                  0.5.6
# multiprocess             0.70.9
# multitasking             0.0.9
# murmurhash               1.0.2
# music21                  5.5.0
# natsort                  5.5.0
# nbconvert                5.6.1
# nbformat                 4.4.0
# networkx                 2.4
# nibabel                  2.3.3
# nltk                     3.2.5
# notebook                 5.2.2
# np-utils                 0.5.11.1
# numba                    0.40.1
# numexpr                  2.7.0
# numpy                    1.17.4
# nvidia-ml-py3            7.352.0
# oauth2client             4.1.3
# oauthlib                 3.1.0
# okgrade                  0.4.3
# olefile                  0.46
# opencv-contrib-python    3.4.3.18
# opencv-python            3.4.7.28
# openpyxl                 2.5.9
# opt-einsum               3.1.0
# osqp                     0.6.1
# packaging                19.2
# palettable               3.3.0
# pandas                   0.25.3
# pandas-datareader        0.7.4
# pandas-gbq               0.11.0
# pandas-profiling         1.4.1
# pandocfilters            1.4.2
# parso                    0.5.1
# pathlib                  1.0.1
# patsy                    0.5.1
# pexpect                  4.7.0
# pickleshare              0.7.5
# Pillow                   4.3.0
# pip                      19.3.1
# pip-tools                4.2.0
# plac                     0.9.6
# plotly                   4.1.1
# plotnine                 0.5.1
# pluggy                   0.7.1
# portpicker               1.2.0
# prefetch-generator       1.0.1
# preshed                  2.0.1
# pretty-midi              0.2.8
# prettytable              0.7.2
# progressbar2             3.38.0
# prometheus-client        0.7.1
# promise                  2.2.1
# prompt-toolkit           1.0.18
# protobuf                 3.10.0
# psutil                   5.4.8
# psycopg2                 2.7.6.1
# ptyprocess               0.6.0
# py                       1.8.0
# pyarrow                  0.14.1
# pyasn1                   0.4.7
# pyasn1-modules           0.2.7
# pycocotools              2.0.0
# pycparser                2.19
# pydata-google-auth       0.1.3
# pydot                    1.3.0
# pydot-ng                 2.0.0
# pydotplus                2.0.2
# PyDrive                  1.3.1
# pyemd                    0.5.1
# pyglet                   1.3.2
# Pygments                 2.1.3
# pygobject                3.26.1
# pymc3                    3.7
# PyMeeus                  0.3.6
# pymongo                  3.9.0
# pymystem3                0.2.0
# PyOpenGL                 3.1.0
# pyparsing                2.4.5
# pypng                    0.0.20
# pyrsistent               0.15.5
# pysndfile                1.3.8
# PySocks                  1.7.1
# pystan                   2.19.1.1
# pytest                   3.6.4
# python-apt               1.6.4
# python-chess             0.23.11
# python-dateutil          2.6.1
# python-louvain           0.13
# python-rtmidi            1.3.1
# python-slugify           4.0.0
# python-utils             2.3.0
# pytz                     2018.9
# PyWavelets               1.1.1
# PyYAML                   3.13
# pyzmq                    17.0.0
# qtconsole                4.6.0
# requests                 2.21.0
# requests-oauthlib        1.3.0
# resampy                  0.2.2
# retrying                 1.3.3
# rpy2                     2.9.5
# rsa                      4.0
# s3fs                     0.4.0
# s3transfer               0.2.1
# scikit-image             0.15.0
# scikit-learn             0.21.3
# scipy                    1.3.2
# screen-resolution-extra  0.0.0
# scs                      2.1.1.post2
# seaborn                  0.9.0
# semantic-version         2.8.2
# Send2Trash               1.5.0
# setuptools               41.6.0
# setuptools-git           1.2
# Shapely                  1.6.4.post2
# simplegeneric            0.8.1
# six                      1.12.0
# sklearn                  0.0
# sklearn-pandas           1.8.0
# smart-open               1.9.0
# snowballstemmer          2.0.0
# sortedcontainers         2.1.0
# spacy                    2.1.9
# Sphinx                   1.8.5
# sphinxcontrib-websupport 1.1.2
# SQLAlchemy               1.3.11
# sqlparse                 0.3.0
# srsly                    0.2.0
# stable-baselines         2.2.1
# statsmodels              0.10.1
# sympy                    1.1.1
# tables                   3.4.4
# tabulate                 0.8.5
# tblib                    1.5.0
# tensor2tensor            1.14.1
# tensorboard              1.15.0
# tensorboardcolab         0.0.22
# tensorflow               1.15.0
# tensorflow-datasets      1.3.0
# tensorflow-estimator     1.15.1
# tensorflow-gan           2.0.0
# tensorflow-hub           0.7.0
# tensorflow-metadata      0.15.1
# tensorflow-privacy       0.2.2
# tensorflow-probability   0.7.0
# termcolor                1.1.0
# terminado                0.8.3
# testpath                 0.4.4
# text-unidecode           1.3
# textblob                 0.15.3
# textgenrnn               1.4.1
# tflearn                  0.3.2
# Theano                   1.0.4
# thinc                    7.0.8
# toolz                    0.10.0
# torch                    1.3.1
# torchsummary             1.5.1
# torchtext                0.3.1
# torchvision              0.4.2
# tornado                  4.5.3
# tqdm                     4.28.1
# traitlets                4.3.3
# tweepy                   3.6.0
# typing                   3.6.6
# typing-extensions        3.6.6
# tzlocal                  1.5.1
# umap-learn               0.3.10
# uritemplate              3.0.0
# urllib3                  1.24.3
# vega-datasets            0.7.0
# wasabi                   0.4.0
# wcwidth                  0.1.7
# webencodings             0.5.1
# Werkzeug                 0.16.0
# wheel                    0.33.6
# widgetsnbextension       3.5.1
# wordcloud                1.5.0
# wrapt                    1.11.2
# xarray                   0.11.3
# xgboost                  0.90
# xkit                     0.0.0
# xlrd                     1.1.0
# xlwt                     1.3.0
# yellowbrick              0.9.1
# zict                     1.0.0
# zipp                     0.6.0
# zmq                      0.0.0

# %% [markdown]
# ## 2-0 更新 runtime，換成 tensorflow-1.13.1

# %%
! pip uninstall -y tensorflow
! pip install tensorflow-gpu==1.13.1
# Out:
# Uninstalling tensorflow-1.15.0:
#   Successfully uninstalled tensorflow-1.15.0
# Collecting tensorflow-gpu==1.13.1
#   Downloading https://files.pythonhosted.org/packages/7b/b1/0ad4ae02e17ddd62109cd54c291e311c4b5fd09b4d0678d3d6ce4159b0f0/tensorflow_gpu-1.13.1-cp36-cp36m-manylinux1_x86_64.whl (345.2MB)
#      |████████████████████████████████| 345.2MB 45kB/s
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (1.1.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (1.12.0)
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (0.8.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (1.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (1.15.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (1.0.8)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (0.8.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (1.17.4)
# Collecting tensorboard<1.14.0,>=1.13.0
#   Downloading https://files.pythonhosted.org/packages/0f/39/bdd75b08a6fba41f098b6cb091b9e8c7a80e1b4d679a581a0ccd17b10373/tensorboard-1.13.1-py3-none-any.whl (3.2MB)
#      |████████████████████████████████| 3.2MB 40.1MB/s
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (0.2.2)
# Collecting tensorflow-estimator<1.14.0rc0,>=1.13.0
#   Downloading https://files.pythonhosted.org/packages/bb/48/13f49fc3fa0fdf916aa1419013bb8f2ad09674c275b4046d5ee669a46873/tensorflow_estimator-1.13.0-py2.py3-none-any.whl (367kB)
#      |████████████████████████████████| 368kB 57.0MB/s
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (0.33.6)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.13.1) (3.10.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==1.13.1) (2.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.1) (3.1.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow-gpu==1.13.1) (0.16.0)
# Collecting mock>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/05/d2/f94e68be6b17f46d2c353564da56e6fb89ef09faeeff3313a046cb810ca9/mock-3.0.5-py2.py3-none-any.whl
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-gpu==1.13.1) (41.6.0)
# Installing collected packages: tensorboard, mock, tensorflow-estimator, tensorflow-gpu
#   Found existing installation: tensorboard 1.15.0
#     Uninstalling tensorboard-1.15.0:
#       Successfully uninstalled tensorboard-1.15.0
#   Found existing installation: tensorflow-estimator 1.15.1
#     Uninstalling tensorflow-estimator-1.15.1:
#       Successfully uninstalled tensorflow-estimator-1.15.1
# Successfully installed mock-3.0.5 tensorboard-1.13.1 tensorflow-estimator-1.13.0 tensorflow-gpu-1.13.1

# %% [markdown]
# ## 2-1 測試是否支援GPU

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))

# %% [markdown]
# ## 2-2 進、出、換 cell
# 1. ENTER進cell
# 2. ESC出cell
# 3. ↑↓換cell

# %% [markdown]
# ## 2-2 上增、下增、刪除、轉換 cell
# 1. CMD/CTRL+m a (above的意思)
# 2. CMD/CTRL+m b (below的意思)
# 3. CMD/CTRL+m d (delete的意思)
# 4. CMD/CTRL+m m/y (轉成text/code)

# %% [markdown]
# ## 2-3 在cell內
# 1. ENTER換行編輯cell
# 2. SHIFT+ENTER執行cell

# %% [markdown]
# ## 2-4 上一步/下一步
# 1. 在cell內：CMD/CTRL+z/y
# 2. 在cell外：CMD/CTRL+SHIFT+z/y

# %% [markdown]
# ## 2-5 Runtime
# 1. restart 重開機的概念
# 2. reset 重置、重灌的概念
# 3. 換成GPU的，GPU的平行運算能大幅縮短神經網路的訓練時間

# %% [markdown]
# # 3- 在 Colab 操作 Linux 指令

# %% [markdown]
# 1. 你的Google雲端硬碟裡的Colab Notebook是跑在1.5hr/12hr自動重置的Linux虛擬機上
# 2. 資料科學、機器學習、深度學習(神經網路)、Google Cloud API相關的Python函式庫皆已安裝
# 3. 現成的AI實驗開發環境，使用Python程式語言
# 4. 前置一個驚嘆號，使用Linux指令操作虛擬機
# 5. 用 && 解決無法停留在 cd 後的工作目錄的問題

# %% [markdown]
# # 4- 訓練（學）

# %% [markdown]
# ## 4-1 安裝 Donkeycar 開發套件

# %%
! git clone https://github.com/autorope/donkeycar
! cd donkeycar && git checkout ec7ea7a
! cd donkeycar && time pip3 install -e .
# Out:
# Cloning into 'donkeycar'...
# remote: Enumerating objects: 10963, done.
# remote: Total 10963 (delta 0), reused 0 (delta 0), pack-reused 10963
# Receiving objects: 100% (10963/10963), 58.79 MiB | 26.39 MiB/s, done.
# Resolving deltas: 100% (6804/6804), done.
# Note: checking out 'ec7ea7a'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>
#
# HEAD is now at ec7ea7a instructions on training behavior model
# Obtaining file:///content/donkeycar
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from donkeycar==3.1.0) (1.17.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from donkeycar==3.1.0) (4.3.0)
# Requirement already satisfied: docopt in /usr/local/lib/python3.6/dist-packages (from donkeycar==3.1.0) (0.6.2)
# Requirement already satisfied: tornado in /usr/local/lib/python3.6/dist-packages (from donkeycar==3.1.0) (4.5.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from donkeycar==3.1.0) (2.21.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from donkeycar==3.1.0) (2.8.0)
# Requirement already satisfied: moviepy in /usr/local/lib/python3.6/dist-packages (from donkeycar==3.1.0) (0.2.3.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from donkeycar==3.1.0) (0.25.3)
# Requirement already satisfied: PrettyTable in /usr/local/lib/python3.6/dist-packages (from donkeycar==3.1.0) (0.7.2)
# Collecting paho-mqtt
#   Downloading https://files.pythonhosted.org/packages/59/11/1dd5c70f0f27a88a3a05772cd95f6087ac479fac66d9c7752ee5e16ddbbc/paho-mqtt-1.5.0.tar.gz (99kB)
#      |████████████████████████████████| 102kB 4.7MB/s
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from pillow->donkeycar==3.1.0) (0.46)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->donkeycar==3.1.0) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->donkeycar==3.1.0) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->donkeycar==3.1.0) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->donkeycar==3.1.0) (1.24.3)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py->donkeycar==3.1.0) (1.12.0)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.6/dist-packages (from moviepy->donkeycar==3.1.0) (4.4.1)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.6/dist-packages (from moviepy->donkeycar==3.1.0) (4.28.1)
# Requirement already satisfied: imageio<3.0,>=2.1.2 in /usr/local/lib/python3.6/dist-packages (from moviepy->donkeycar==3.1.0) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas->donkeycar==3.1.0) (2.6.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->donkeycar==3.1.0) (2018.9)
# Building wheels for collected packages: paho-mqtt
#   Building wheel for paho-mqtt (setup.py) ... done
#   Created wheel for paho-mqtt: filename=paho_mqtt-1.5.0-cp36-none-any.whl size=61416 sha256=d15b7a48bb09ae57631944f665772e77a63e50fb794d3bfb7199a27d4537a758
#   Stored in directory: /root/.cache/pip/wheels/02/94/6c/8474137cb7a5a3e001d70a22c8ff919caee69435376bccce79
# Successfully built paho-mqtt
# Installing collected packages: paho-mqtt, donkeycar
#   Running setup.py develop for donkeycar
# Successfully installed donkeycar paho-mqtt-1.5.0
#
# real	0m4.898s
# user	0m4.180s
# sys	0m0.526s

# %% [markdown]
# ## 4-2 安裝搖桿程式

# %%
! git clone https://github.com/raspberrypi-tw/donkeypart_ps3_controller
! cd donkeypart_ps3_controller && python3 setup.py install
# Out:
# Cloning into 'donkeypart_ps3_controller'...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 112 (delta 14), reused 25 (delta 9), pack-reused 76
# Receiving objects: 100% (112/112), 59.13 KiB | 651.00 KiB/s, done.
# Resolving deltas: 100% (45/45), done.
# running install
# running bdist_egg
# running egg_info
# creating donkeypart_ps3_controller.egg-info
# writing donkeypart_ps3_controller.egg-info/PKG-INFO
# writing dependency_links to donkeypart_ps3_controller.egg-info/dependency_links.txt
# writing top-level names to donkeypart_ps3_controller.egg-info/top_level.txt
# writing manifest file 'donkeypart_ps3_controller.egg-info/SOURCES.txt'
# writing manifest file 'donkeypart_ps3_controller.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/donkeypart_ps3_controller
# copying donkeypart_ps3_controller/__init__.py -> build/lib/donkeypart_ps3_controller
# copying donkeypart_ps3_controller/part.py -> build/lib/donkeypart_ps3_controller
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/donkeypart_ps3_controller
# copying build/lib/donkeypart_ps3_controller/__init__.py -> build/bdist.linux-x86_64/egg/donkeypart_ps3_controller
# copying build/lib/donkeypart_ps3_controller/part.py -> build/bdist.linux-x86_64/egg/donkeypart_ps3_controller
# byte-compiling build/bdist.linux-x86_64/egg/donkeypart_ps3_controller/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/donkeypart_ps3_controller/part.py to part.cpython-36.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying donkeypart_ps3_controller.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying donkeypart_ps3_controller.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying donkeypart_ps3_controller.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying donkeypart_ps3_controller.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating dist
# creating 'dist/donkeypart_ps3_controller-0.0-py3.6.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing donkeypart_ps3_controller-0.0-py3.6.egg
# Copying donkeypart_ps3_controller-0.0-py3.6.egg to /usr/local/lib/python3.6/dist-packages
# Adding donkeypart-ps3-controller 0.0 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/donkeypart_ps3_controller-0.0-py3.6.egg
# Processing dependencies for donkeypart-ps3-controller==0.0
# Finished processing dependencies for donkeypart-ps3-controller==0.0

# %% [markdown]
# ## 4-3-1 完整複製（git clone）從樹莓派上傳（git push）至 GitHub 的 Repo

# %%
# 從 github 拉下你的<ID> mycar<REPO>
! git clone https://github.com/youyalin/mycar
# Out:
# fatal: destination path 'mycar' already exists and is not an empty directory.

# %%
# 複製 sample_manage.py 到 <REPO>
! cp donkeypart_ps3_controller/sample_manage.py mycar

# %% [markdown]
# ## 4-3-2 下載差異（git pull）從樹莓派上傳（git push）至 GitHub 的 Repo

# %%
# 更新 Colab <REPO> 資料
! cd mycar && git pull
# Out:
# Already up to date.

# %% [markdown]
# #刪除不要的訓練版本

# %%
#! cd mycar && rm -rf data/tub_1_2_3_4_5_6_7_8_9_10

# %% [markdown]
# ## 4-4 訓練各種深度神經網路 aka 深度學習模型
# 1. model 自行命名，但副檔名必須是.h5
# 2. type 選項
# https://github.com/autorope/donkeycar/blob/dev/donkeycar/templates/train.py#L13
# 3. DonkeyCar已實作的各種模型的說明和比較
# http://docs.donkeycar.com/parts/keras/
# 4. batch = 一次訓練的樣本數
# epoch = 完整訓練的回合數

# %%
! ls mycar/data
# Out:
# tub_10_19-11-23  tub_15_19-11-24  tub_21_19-11-24  tub_4_19-11-23
# tub_11_19-11-23  tub_16_19-11-24  tub_2_19-11-23   tub_5_19-11-23
# tub_1_19-11-23	 tub_17_19-11-24  tub_22_19-11-24  tub_6_19-11-23
# tub_12_19-11-23  tub_18_19-11-24  tub_23_19-11-24  tub_7_19-11-23
# tub_13_19-11-23  tub_19_19-11-24  tub_24_19-11-24  tub_8_19-11-23
# tub_14_19-11-24  tub_20_19-11-24  tub_3_19-11-23   tub_9_19-11-23

# %%
# 進到 <REPO> 以後進行訓練，預設使用 linear
! mkdir mycar/models
#! cd mycar && python sample_manage.py train --model models/lin_1.h5  # --tub data/tub資料夾名稱,data/tub資料夾名稱,...
#! cd mycar && python sample_manage.py train --model models/lin_2.h5  # --tub data/tub資料夾名稱,data/tub資料夾名稱,...
#! cd mycar && python sample_manage.py train --model models/lin_3.h5  --tub data/tub_19_19-11-24,data/tub__19-11-24
! cd mycar && python sample_manage.py train --model models/lin_4.h5  --tub data/tub_16_19-11-24,data/tub_19_19-11-24,data/tub_24_19-11-24
# Out:
# mkdir: cannot create directory ‘mycar/models’: File exists
# using donkey v3.1.0 ...
# loading config file: /content/mycar/config.py
# loading personal config over-rides
#
# config loaded
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 2019-11-24 08:52:55.801376: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-11-24 08:52:55.904119: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-11-24 08:52:55.905021: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x20054a0 executing computations on platform CUDA. Devices:
# 2019-11-24 08:52:55.905054: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2019-11-24 08:52:55.906819: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-11-24 08:52:55.907170: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x2005340 executing computations on platform Host. Devices:
# 2019-11-24 08:52:55.907203: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-11-24 08:52:55.907398: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# totalMemory: 15.90GiB freeMemory: 15.64GiB
# 2019-11-24 08:52:55.907457: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-11-24 08:52:55.908669: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-11-24 08:52:55.908694: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-11-24 08:52:55.908719: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-11-24 08:52:55.908870: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# "get_model_by_type" model Type is: linear
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# training with model type <class 'donkeycar.parts.keras.KerasLinear'>
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img_in (InputLayer)             (None, 120, 160, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 58, 78, 24)   1824        img_in[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 58, 78, 24)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 27, 37, 32)   19232       dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 27, 37, 32)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 12, 17, 64)   51264       dropout_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 12, 17, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 10, 15, 64)   36928       dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 10, 15, 64)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 8, 13, 64)    36928       dropout_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 8, 13, 64)    0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# flattened (Flatten)             (None, 6656)         0           dropout_4[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 100)          665700      flattened[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 100)          0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 50)           5050        dropout_5[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 50)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# n_outputs0 (Dense)              (None, 1)            51          dropout_6[0][0]
# __________________________________________________________________________________________________
# n_outputs1 (Dense)              (None, 1)            51          dropout_6[0][0]
# ==================================================================================================
# Total params: 817,028
# Trainable params: 817,028
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# found 0 pickles writing json records and images in tub data/tub_16_19-11-24
# found 0 pickles writing json records and images in tub data/tub_19_19-11-24
# found 0 pickles writing json records and images in tub data/tub_24_19-11-24
# data/tub_16_19-11-24
# data/tub_19_19-11-24
# data/tub_24_19-11-24
# collating 18805 records ...
# train: 15044, val: 3761
# total records: 18805
# steps_per_epoch 117
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 2019-11-24 08:53:01.386775: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# 29/29 [==============================] - 5s 159ms/step - loss: 0.1841 - n_outputs0_loss: 0.1827 - n_outputs1_loss: 0.0014
#
# Epoch 00001: val_loss improved from inf to 0.18410, saving model to models/lin_4.h5
# 117/117 [==============================] - 23s 197ms/step - loss: 0.2317 - n_outputs0_loss: 0.2151 - n_outputs1_loss: 0.0166 - val_loss: 0.1841 - val_n_outputs0_loss: 0.1827 - val_n_outputs1_loss: 0.0014
# Epoch 2/100
# 29/29 [==============================] - 1s 23ms/step - loss: 0.1693 - n_outputs0_loss: 0.1687 - n_outputs1_loss: 6.0279e-04
#
# Epoch 00002: val_loss improved from 0.18410 to 0.16934, saving model to models/lin_4.h5
# 117/117 [==============================] - 5s 42ms/step - loss: 0.1825 - n_outputs0_loss: 0.1757 - n_outputs1_loss: 0.0068 - val_loss: 0.1693 - val_n_outputs0_loss: 0.1687 - val_n_outputs1_loss: 6.0279e-04
# Epoch 3/100
# 29/29 [==============================] - 1s 22ms/step - loss: 0.1654 - n_outputs0_loss: 0.1644 - n_outputs1_loss: 0.0011
#
# Epoch 00003: val_loss improved from 0.16934 to 0.16545, saving model to models/lin_4.h5
# 117/117 [==============================] - 5s 42ms/step - loss: 0.1728 - n_outputs0_loss: 0.1679 - n_outputs1_loss: 0.0049 - val_loss: 0.1654 - val_n_outputs0_loss: 0.1644 - val_n_outputs1_loss: 0.0011
# Epoch 4/100
# 29/29 [==============================] - 1s 20ms/step - loss: 0.1641 - n_outputs0_loss: 0.1633 - n_outputs1_loss: 7.8627e-04
#
# Epoch 00004: val_loss improved from 0.16545 to 0.16412, saving model to models/lin_4.h5
# 117/117 [==============================] - 5s 41ms/step - loss: 0.1642 - n_outputs0_loss: 0.1605 - n_outputs1_loss: 0.0037 - val_loss: 0.1641 - val_n_outputs0_loss: 0.1633 - val_n_outputs1_loss: 7.8627e-04
# Epoch 5/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.1608 - n_outputs0_loss: 0.1601 - n_outputs1_loss: 7.2817e-04
#
# Epoch 00005: val_loss improved from 0.16412 to 0.16080, saving model to models/lin_4.h5
# 117/117 [==============================] - 5s 40ms/step - loss: 0.1572 - n_outputs0_loss: 0.1541 - n_outputs1_loss: 0.0031 - val_loss: 0.1608 - val_n_outputs0_loss: 0.1601 - val_n_outputs1_loss: 7.2817e-04
# Epoch 6/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.1497 - n_outputs0_loss: 0.1491 - n_outputs1_loss: 5.3208e-04
#
# Epoch 00006: val_loss improved from 0.16080 to 0.14966, saving model to models/lin_4.h5
# 117/117 [==============================] - 5s 40ms/step - loss: 0.1506 - n_outputs0_loss: 0.1482 - n_outputs1_loss: 0.0024 - val_loss: 0.1497 - val_n_outputs0_loss: 0.1491 - val_n_outputs1_loss: 5.3208e-04
# Epoch 7/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.1514 - n_outputs0_loss: 0.1511 - n_outputs1_loss: 2.9847e-04
#
# Epoch 00007: val_loss did not improve from 0.14966
# 117/117 [==============================] - 5s 40ms/step - loss: 0.1463 - n_outputs0_loss: 0.1443 - n_outputs1_loss: 0.0020 - val_loss: 0.1514 - val_n_outputs0_loss: 0.1511 - val_n_outputs1_loss: 2.9847e-04
# Epoch 8/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.1477 - n_outputs0_loss: 0.1473 - n_outputs1_loss: 3.2134e-04
#
# Epoch 00008: val_loss improved from 0.14966 to 0.14766, saving model to models/lin_4.h5
# 117/117 [==============================] - 5s 41ms/step - loss: 0.1431 - n_outputs0_loss: 0.1413 - n_outputs1_loss: 0.0018 - val_loss: 0.1477 - val_n_outputs0_loss: 0.1473 - val_n_outputs1_loss: 3.2134e-04
# Epoch 9/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.1501 - n_outputs0_loss: 0.1499 - n_outputs1_loss: 2.3006e-04
#
# Epoch 00009: val_loss did not improve from 0.14766
# 117/117 [==============================] - 5s 40ms/step - loss: 0.1395 - n_outputs0_loss: 0.1379 - n_outputs1_loss: 0.0016 - val_loss: 0.1501 - val_n_outputs0_loss: 0.1499 - val_n_outputs1_loss: 2.3006e-04
# Epoch 10/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.1422 - n_outputs0_loss: 0.1420 - n_outputs1_loss: 2.6199e-04
#
# Epoch 00010: val_loss improved from 0.14766 to 0.14222, saving model to models/lin_4.h5
# 117/117 [==============================] - 5s 40ms/step - loss: 0.1348 - n_outputs0_loss: 0.1333 - n_outputs1_loss: 0.0015 - val_loss: 0.1422 - val_n_outputs0_loss: 0.1420 - val_n_outputs1_loss: 2.6199e-04
# Epoch 11/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.1478 - n_outputs0_loss: 0.1475 - n_outputs1_loss: 3.1554e-04
#
# Epoch 00011: val_loss did not improve from 0.14222
# 117/117 [==============================] - 5s 39ms/step - loss: 0.1319 - n_outputs0_loss: 0.1305 - n_outputs1_loss: 0.0015 - val_loss: 0.1478 - val_n_outputs0_loss: 0.1475 - val_n_outputs1_loss: 3.1554e-04
# Epoch 12/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.1412 - n_outputs0_loss: 0.1411 - n_outputs1_loss: 1.8056e-04
#
# Epoch 00012: val_loss improved from 0.14222 to 0.14124, saving model to models/lin_4.h5
# 117/117 [==============================] - 5s 40ms/step - loss: 0.1272 - n_outputs0_loss: 0.1259 - n_outputs1_loss: 0.0013 - val_loss: 0.1412 - val_n_outputs0_loss: 0.1411 - val_n_outputs1_loss: 1.8056e-04
# Epoch 13/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.1390 - n_outputs0_loss: 0.1388 - n_outputs1_loss: 1.9964e-04
#
# Epoch 00013: val_loss improved from 0.14124 to 0.13897, saving model to models/lin_4.h5
# 117/117 [==============================] - 5s 40ms/step - loss: 0.1204 - n_outputs0_loss: 0.1191 - n_outputs1_loss: 0.0013 - val_loss: 0.1390 - val_n_outputs0_loss: 0.1388 - val_n_outputs1_loss: 1.9964e-04
# Epoch 14/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.1392 - n_outputs0_loss: 0.1390 - n_outputs1_loss: 2.1384e-04
#
# Epoch 00014: val_loss did not improve from 0.13897
# 117/117 [==============================] - 5s 40ms/step - loss: 0.1160 - n_outputs0_loss: 0.1149 - n_outputs1_loss: 0.0012 - val_loss: 0.1392 - val_n_outputs0_loss: 0.1390 - val_n_outputs1_loss: 2.1384e-04
# Epoch 15/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.1367 - n_outputs0_loss: 0.1366 - n_outputs1_loss: 1.7731e-04
#
# Epoch 00015: val_loss improved from 0.13897 to 0.13673, saving model to models/lin_4.h5
# 117/117 [==============================] - 5s 40ms/step - loss: 0.1127 - n_outputs0_loss: 0.1116 - n_outputs1_loss: 0.0011 - val_loss: 0.1367 - val_n_outputs0_loss: 0.1366 - val_n_outputs1_loss: 1.7731e-04
# Epoch 16/100
# 29/29 [==============================] - 1s 17ms/step - loss: 0.1421 - n_outputs0_loss: 0.1419 - n_outputs1_loss: 1.9227e-04
#
# Epoch 00016: val_loss did not improve from 0.13673
# 117/117 [==============================] - 5s 40ms/step - loss: 0.1086 - n_outputs0_loss: 0.1075 - n_outputs1_loss: 0.0010 - val_loss: 0.1421 - val_n_outputs0_loss: 0.1419 - val_n_outputs1_loss: 1.9227e-04
# Epoch 17/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.1358 - n_outputs0_loss: 0.1357 - n_outputs1_loss: 1.4820e-04
#
# Epoch 00017: val_loss improved from 0.13673 to 0.13580, saving model to models/lin_4.h5
# 117/117 [==============================] - 5s 40ms/step - loss: 0.1041 - n_outputs0_loss: 0.1032 - n_outputs1_loss: 9.2827e-04 - val_loss: 0.1358 - val_n_outputs0_loss: 0.1357 - val_n_outputs1_loss: 1.4820e-04
# Epoch 18/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.1378 - n_outputs0_loss: 0.1376 - n_outputs1_loss: 1.5038e-04
#
# Epoch 00018: val_loss did not improve from 0.13580
# 117/117 [==============================] - 5s 39ms/step - loss: 0.1006 - n_outputs0_loss: 0.0998 - n_outputs1_loss: 8.3694e-04 - val_loss: 0.1378 - val_n_outputs0_loss: 0.1376 - val_n_outputs1_loss: 1.5038e-04
# Epoch 19/100
# 29/29 [==============================] - 1s 17ms/step - loss: 0.1368 - n_outputs0_loss: 0.1366 - n_outputs1_loss: 1.2847e-04
#
# Epoch 00019: val_loss did not improve from 0.13580
# 117/117 [==============================] - 5s 39ms/step - loss: 0.0947 - n_outputs0_loss: 0.0940 - n_outputs1_loss: 7.8478e-04 - val_loss: 0.1368 - val_n_outputs0_loss: 0.1366 - val_n_outputs1_loss: 1.2847e-04
# Epoch 20/100
# 29/29 [==============================] - 1s 19ms/step - loss: 0.1312 - n_outputs0_loss: 0.1310 - n_outputs1_loss: 1.9794e-04
#
# Epoch 00020: val_loss improved from 0.13580 to 0.13124, saving model to models/lin_4.h5
# 117/117 [==============================] - 5s 40ms/step - loss: 0.0906 - n_outputs0_loss: 0.0898 - n_outputs1_loss: 7.7687e-04 - val_loss: 0.1312 - val_n_outputs0_loss: 0.1310 - val_n_outputs1_loss: 1.9794e-04
# Epoch 21/100
# 29/29 [==============================] - 1s 17ms/step - loss: 0.1323 - n_outputs0_loss: 0.1321 - n_outputs1_loss: 1.8103e-04
#
# Epoch 00021: val_loss did not improve from 0.13124
# 117/117 [==============================] - 5s 40ms/step - loss: 0.0865 - n_outputs0_loss: 0.0858 - n_outputs1_loss: 6.8753e-04 - val_loss: 0.1323 - val_n_outputs0_loss: 0.1321 - val_n_outputs1_loss: 1.8103e-04
# Epoch 22/100
# 29/29 [==============================] - 0s 17ms/step - loss: 0.1305 - n_outputs0_loss: 0.1304 - n_outputs1_loss: 1.4169e-04
#
# Epoch 00022: val_loss improved from 0.13124 to 0.13050, saving model to models/lin_4.h5
# 117/117 [==============================] - 5s 40ms/step - loss: 0.0818 - n_outputs0_loss: 0.0812 - n_outputs1_loss: 5.9368e-04 - val_loss: 0.1305 - val_n_outputs0_loss: 0.1304 - val_n_outputs1_loss: 1.4169e-04
# Epoch 23/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.1382 - n_outputs0_loss: 0.1381 - n_outputs1_loss: 1.5937e-04
#
# Epoch 00023: val_loss did not improve from 0.13050
# 117/117 [==============================] - 5s 40ms/step - loss: 0.0782 - n_outputs0_loss: 0.0776 - n_outputs1_loss: 5.5243e-04 - val_loss: 0.1382 - val_n_outputs0_loss: 0.1381 - val_n_outputs1_loss: 1.5937e-04
# Epoch 24/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.1327 - n_outputs0_loss: 0.1326 - n_outputs1_loss: 1.2004e-04
#
# Epoch 00024: val_loss did not improve from 0.13050
# 117/117 [==============================] - 5s 40ms/step - loss: 0.0754 - n_outputs0_loss: 0.0749 - n_outputs1_loss: 4.7947e-04 - val_loss: 0.1327 - val_n_outputs0_loss: 0.1326 - val_n_outputs1_loss: 1.2004e-04
# Epoch 25/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.1318 - n_outputs0_loss: 0.1317 - n_outputs1_loss: 9.1870e-05
#
# Epoch 00025: val_loss did not improve from 0.13050
# 117/117 [==============================] - 5s 40ms/step - loss: 0.0698 - n_outputs0_loss: 0.0694 - n_outputs1_loss: 4.0649e-04 - val_loss: 0.1318 - val_n_outputs0_loss: 0.1317 - val_n_outputs1_loss: 9.1870e-05
# Epoch 26/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.1330 - n_outputs0_loss: 0.1329 - n_outputs1_loss: 8.9666e-05
#
# Epoch 00026: val_loss did not improve from 0.13050
# 117/117 [==============================] - 5s 40ms/step - loss: 0.0685 - n_outputs0_loss: 0.0682 - n_outputs1_loss: 3.6655e-04 - val_loss: 0.1330 - val_n_outputs0_loss: 0.1329 - val_n_outputs1_loss: 8.9666e-05
# Epoch 27/100
# 29/29 [==============================] - 1s 18ms/step - loss: 0.1365 - n_outputs0_loss: 0.1364 - n_outputs1_loss: 8.6684e-05
#
# Epoch 00027: val_loss did not improve from 0.13050
# 117/117 [==============================] - 5s 40ms/step - loss: 0.0652 - n_outputs0_loss: 0.0648 - n_outputs1_loss: 3.3195e-04 - val_loss: 0.1365 - val_n_outputs0_loss: 0.1364 - val_n_outputs1_loss: 8.6684e-05
# Epoch 00027: early stopping
# Training completed in 0:02:28.
#
#
# ----------- Best Eval Loss :0.130500 ---------
# <Figure size 640x480 with 1 Axes>

# %%
# 進到 <REPO> 以後進行訓練，這次使用 rnn
! mkdir mycar/models
! cd mycar && python sample_manage.py train --model models/rnn_1.h5 --type rnn --tub data/tub_16_19-11-24,data/tub_19_19-11-24,data/tub_24_19-11-24
# Out:
# mkdir: cannot create directory ‘mycar/models’: File exists
# using donkey v3.1.0 ...
# loading config file: /content/mycar/config.py
# loading personal config over-rides
#
# config loaded
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 2019-11-24 08:56:21.456984: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-11-24 08:56:21.567175: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-11-24 08:56:21.568145: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x18114a0 executing computations on platform CUDA. Devices:
# 2019-11-24 08:56:21.568182: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2019-11-24 08:56:21.570011: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2019-11-24 08:56:21.570475: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x1811340 executing computations on platform Host. Devices:
# 2019-11-24 08:56:21.570512: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 2019-11-24 08:56:21.570700: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1433] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# totalMemory: 15.90GiB freeMemory: 15.64GiB
# 2019-11-24 08:56:21.570735: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1512] Adding visible gpu devices: 0
# 2019-11-24 08:56:21.571778: I tensorflow/core/common_runtime/gpu/gpu_device.cc:984] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-11-24 08:56:21.571809: I tensorflow/core/common_runtime/gpu/gpu_device.cc:990]      0
# 2019-11-24 08:56:21.571824: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1003] 0:   N
# 2019-11-24 08:56:21.571898: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 15216 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# sequence of images training
# "get_model_by_type" model Type is: rnn
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Tub: data/tub_16_19-11-24 has 4670 records
# Tub: data/tub_19_19-11-24 has 3811 records
# Tub: data/tub_24_19-11-24 has 10324 records
# collating records
# collating sequences
# collated 18799 sequences of length 3
# train: 15040, validation: 3759
# steps_per_epoch 117
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 2019-11-24 08:56:31.729574: I tensorflow/stream_executor/dso_loader.cc:152] successfully opened CUDA library libcublas.so.10.0 locally
# 29/29 [==============================] - 3s 89ms/step - loss: 0.1040
#
# Epoch 00001: val_loss improved from inf to 0.10405, saving model to models/rnn_1.h5
# 117/117 [==============================] - 25s 216ms/step - loss: 0.1175 - val_loss: 0.1040
# Epoch 2/100
# 29/29 [==============================] - 2s 54ms/step - loss: 0.0834
#
# Epoch 00002: val_loss improved from 0.10405 to 0.08335, saving model to models/rnn_1.h5
# 117/117 [==============================] - 13s 110ms/step - loss: 0.0898 - val_loss: 0.0834
# Epoch 3/100
# 29/29 [==============================] - 2s 55ms/step - loss: 0.0839
#
# Epoch 00003: val_loss did not improve from 0.08335
# 117/117 [==============================] - 13s 110ms/step - loss: 0.0854 - val_loss: 0.0839
# Epoch 4/100
# 29/29 [==============================] - 2s 54ms/step - loss: 0.0801
#
# Epoch 00004: val_loss improved from 0.08335 to 0.08006, saving model to models/rnn_1.h5
# 117/117 [==============================] - 13s 110ms/step - loss: 0.0804 - val_loss: 0.0801
# Epoch 5/100
# 29/29 [==============================] - 2s 55ms/step - loss: 0.0801
#
# Epoch 00005: val_loss did not improve from 0.08006
# 117/117 [==============================] - 13s 110ms/step - loss: 0.0780 - val_loss: 0.0801
# Epoch 6/100
# 29/29 [==============================] - 2s 55ms/step - loss: 0.0797
#
# Epoch 00006: val_loss improved from 0.08006 to 0.07972, saving model to models/rnn_1.h5
# 117/117 [==============================] - 13s 110ms/step - loss: 0.0765 - val_loss: 0.0797
# Epoch 7/100
# 29/29 [==============================] - 2s 56ms/step - loss: 0.0784
#
# Epoch 00007: val_loss improved from 0.07972 to 0.07843, saving model to models/rnn_1.h5
# 117/117 [==============================] - 13s 112ms/step - loss: 0.0757 - val_loss: 0.0784
# Epoch 8/100
# 29/29 [==============================] - 2s 56ms/step - loss: 0.0787
#
# Epoch 00008: val_loss did not improve from 0.07843
# 117/117 [==============================] - 13s 110ms/step - loss: 0.0723 - val_loss: 0.0787
# Epoch 9/100
# 29/29 [==============================] - 2s 55ms/step - loss: 0.0778
#
# Epoch 00009: val_loss improved from 0.07843 to 0.07776, saving model to models/rnn_1.h5
# 117/117 [==============================] - 13s 110ms/step - loss: 0.0715 - val_loss: 0.0778
# Epoch 10/100
# 29/29 [==============================] - 2s 56ms/step - loss: 0.0726
#
# Epoch 00010: val_loss improved from 0.07776 to 0.07263, saving model to models/rnn_1.h5
# 117/117 [==============================] - 13s 112ms/step - loss: 0.0717 - val_loss: 0.0726
# Epoch 11/100
# 29/29 [==============================] - 2s 56ms/step - loss: 0.0742
#
# Epoch 00011: val_loss did not improve from 0.07263
# 117/117 [==============================] - 13s 111ms/step - loss: 0.0706 - val_loss: 0.0742
# Epoch 12/100
# 29/29 [==============================] - 2s 58ms/step - loss: 0.0719
#
# Epoch 00012: val_loss improved from 0.07263 to 0.07190, saving model to models/rnn_1.h5
# 117/117 [==============================] - 13s 111ms/step - loss: 0.0687 - val_loss: 0.0719
# Epoch 13/100
# 29/29 [==============================] - 2s 56ms/step - loss: 0.0741
#
# Epoch 00013: val_loss did not improve from 0.07190
# 117/117 [==============================] - 13s 111ms/step - loss: 0.0670 - val_loss: 0.0741
# Epoch 14/100
# 29/29 [==============================] - 2s 57ms/step - loss: 0.0710
#
# Epoch 00014: val_loss improved from 0.07190 to 0.07098, saving model to models/rnn_1.h5
# 117/117 [==============================] - 13s 111ms/step - loss: 0.0666 - val_loss: 0.0710
# Epoch 15/100
# 29/29 [==============================] - 2s 56ms/step - loss: 0.0711
#
# Epoch 00015: val_loss did not improve from 0.07098
# 117/117 [==============================] - 13s 111ms/step - loss: 0.0660 - val_loss: 0.0711
# Epoch 16/100
# 29/29 [==============================] - 2s 58ms/step - loss: 0.0717
#
# Epoch 00016: val_loss did not improve from 0.07098
# 117/117 [==============================] - 13s 111ms/step - loss: 0.0629 - val_loss: 0.0717
# Epoch 17/100
# 29/29 [==============================] - 2s 56ms/step - loss: 0.0698
#
# Epoch 00017: val_loss improved from 0.07098 to 0.06983, saving model to models/rnn_1.h5
# 117/117 [==============================] - 13s 112ms/step - loss: 0.0631 - val_loss: 0.0698
# Epoch 18/100
# 29/29 [==============================] - 2s 56ms/step - loss: 0.0697
#
# Epoch 00018: val_loss improved from 0.06983 to 0.06974, saving model to models/rnn_1.h5
# 117/117 [==============================] - 13s 111ms/step - loss: 0.0618 - val_loss: 0.0697
# Epoch 19/100
# 29/29 [==============================] - 2s 57ms/step - loss: 0.0697
#
# Epoch 00019: val_loss improved from 0.06974 to 0.06972, saving model to models/rnn_1.h5
# 117/117 [==============================] - 13s 112ms/step - loss: 0.0614 - val_loss: 0.0697
# Epoch 20/100
# 29/29 [==============================] - 2s 55ms/step - loss: 0.0699
#
# Epoch 00020: val_loss did not improve from 0.06972
# 117/117 [==============================] - 13s 111ms/step - loss: 0.0598 - val_loss: 0.0699
# Epoch 21/100
# 29/29 [==============================] - 2s 57ms/step - loss: 0.0677
#
# Epoch 00021: val_loss improved from 0.06972 to 0.06772, saving model to models/rnn_1.h5
# 117/117 [==============================] - 13s 111ms/step - loss: 0.0603 - val_loss: 0.0677
# Epoch 22/100
# 29/29 [==============================] - 2s 56ms/step - loss: 0.0675
#
# Epoch 00022: val_loss improved from 0.06772 to 0.06753, saving model to models/rnn_1.h5
# 117/117 [==============================] - 13s 110ms/step - loss: 0.0586 - val_loss: 0.0675
# Epoch 23/100
# 29/29 [==============================] - 2s 56ms/step - loss: 0.0663
#
# Epoch 00023: val_loss improved from 0.06753 to 0.06634, saving model to models/rnn_1.h5
# 117/117 [==============================] - 13s 110ms/step - loss: 0.0591 - val_loss: 0.0663
# Epoch 24/100
# 29/29 [==============================] - 2s 56ms/step - loss: 0.0671
#
# Epoch 00024: val_loss did not improve from 0.06634
# 117/117 [==============================] - 13s 109ms/step - loss: 0.0567 - val_loss: 0.0671
# Epoch 25/100
# 29/29 [==============================] - 2s 56ms/step - loss: 0.0661
#
# Epoch 00025: val_loss improved from 0.06634 to 0.06608, saving model to models/rnn_1.h5
# 117/117 [==============================] - 13s 110ms/step - loss: 0.0562 - val_loss: 0.0661
# Epoch 26/100
# 29/29 [==============================] - 2s 56ms/step - loss: 0.0638
#
# Epoch 00026: val_loss improved from 0.06608 to 0.06376, saving model to models/rnn_1.h5
# 117/117 [==============================] - 13s 110ms/step - loss: 0.0553 - val_loss: 0.0638
# Epoch 27/100
# 29/29 [==============================] - 2s 57ms/step - loss: 0.0643
#
# Epoch 00027: val_loss did not improve from 0.06376
# 117/117 [==============================] - 13s 111ms/step - loss: 0.0544 - val_loss: 0.0643
# Epoch 28/100
# 29/29 [==============================] - 2s 56ms/step - loss: 0.0679
#
# Epoch 00028: val_loss did not improve from 0.06376
# 117/117 [==============================] - 13s 110ms/step - loss: 0.0537 - val_loss: 0.0679
# Epoch 29/100
# 29/29 [==============================] - 2s 54ms/step - loss: 0.0643
#
# Epoch 00029: val_loss did not improve from 0.06376
# 117/117 [==============================] - 13s 110ms/step - loss: 0.0532 - val_loss: 0.0643
# Epoch 30/100
# 29/29 [==============================] - 2s 56ms/step - loss: 0.0659
#
# Epoch 00030: val_loss did not improve from 0.06376
# 117/117 [==============================] - 13s 110ms/step - loss: 0.0525 - val_loss: 0.0659
# Epoch 31/100
# 29/29 [==============================] - 2s 55ms/step - loss: 0.0647
#
# Epoch 00031: val_loss did not improve from 0.06376
# 117/117 [==============================] - 13s 109ms/step - loss: 0.0534 - val_loss: 0.0647
# Epoch 00031: early stopping
# Training completed in 0:06:56.
#
#
# ----------- Best Eval Loss :0.063764 ---------
# <Figure size 640x480 with 1 Axes>

# %% [markdown]
# ## 4-5 遷移學習（增加訓練、增加技能）

# %%
! cd mycar && python sample_manage.py train --transfer models/rnn_1.h5 --model models/rnn_2.h5 --type rnn

# %% [markdown]
# # 5- 推論（用）
